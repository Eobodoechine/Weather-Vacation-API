# %%
# Dependencies and Setup
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import linregress
import matplotlib.pyplot as plt
from citipy import citipy
from api_keyz import (yeehaw)
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=2000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
citiespd = pd.DataFrame(cities,columns=['City'])
citiespd["Latitude"] = ""
citiespd["Longitude"] = ""
citiespd["Humidity"] = ""
citiespd["Cloudiness"] = ""
citiespd["Max Temperature"] = ""
citiespd["Wind Speed"] = ""
citiespd["Country"] = ""
citiespd["Date"] = ""
citiespd.head()
# Out:
# 746
#            City Latitude Longitude Humidity Cloudiness Max Temperature  \
# 0  jacareacanga
# 1         vaini
# 2    the valley
# 3       malanje
# 4        riyadh
#
#   Wind Speed Country Date
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# ###### Weather check on each city using a series of successive API calls.
# ###### Includes a print log of each city as it's being processed.

# %%
url="http://api.openweathermap.org/data/2.5/weather?"
print("Beginning Data Retrieval")
print("-----------------------------")
for index, row in citiespd.iterrows():
    city=row['City']
    weather_url = f"{url}q={city}&appid={yeehaw}"
    weatherz = weather_url.replace(' ','')
    weather = requests.get(weatherz).json()
    try:     
        print(f"Processing Record {index} | {city}")
        citiespd.loc[index, "Latitude"] = weather["coord"]["lat"]
        citiespd.loc[index, "Longitude"] = weather["coord"]["lon"]
        citiespd.loc[index, "Humidity"] = weather["main"]["humidity"]
        citiespd.loc[index, "Cloudiness"] = weather["clouds"]["all"]
        citiespd.loc[index, "Max Temperature"] = weather["main"]["temp_max"]
        citiespd.loc[index, "Wind Speed"] = weather["wind"]["speed"]
        citiespd.loc[index, "Country"] = weather["sys"]["country"]
        citiespd.loc[index, "Date"] = weather["dt"]
    except (KeyError, IndexError): 
        print("{city} not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 | jacareacanga
# Processing Record 1 | vaini
# Processing Record 2 | the valley
# {city} not found. Skipping...
# Processing Record 3 | malanje
# Processing Record 4 | riyadh
# Processing Record 5 | hobart
# Processing Record 6 | luocheng
# Processing Record 7 | vaitupu
# {city} not found. Skipping...
# Processing Record 8 | kushmurun
# Processing Record 9 | dmytrivka
# Processing Record 10 | marcona
# {city} not found. Skipping...
# Processing Record 11 | atuona
# Processing Record 12 | cartagena
# Processing Record 13 | hermanus
# Processing Record 14 | kailua
# Processing Record 15 | yellowknife
# Processing Record 16 | leningradskiy
# Processing Record 17 | margate
# Processing Record 18 | gambela
# Processing Record 19 | new norfolk
# {city} not found. Skipping...
# Processing Record 20 | cape town
# {city} not found. Skipping...
# Processing Record 21 | tabiauea
# {city} not found. Skipping...
# Processing Record 22 | alice springs
# {city} not found. Skipping...
# Processing Record 23 | dergachi
# Processing Record 24 | ouesso
# Processing Record 25 | naron
# Processing Record 26 | port alfred
# {city} not found. Skipping...
# Processing Record 27 | bethel
# Processing Record 28 | bonthe
# Processing Record 29 | tilichiki
# Processing Record 30 | lasa
# Processing Record 31 | nikolskoye
# Processing Record 32 | luderitz
# Processing Record 33 | ushuaia
# Processing Record 34 | bluff
# Processing Record 35 | clyde river
# {city} not found. Skipping...
# Processing Record 36 | araguacu
# Processing Record 37 | bud
# Processing Record 38 | nizhneyansk
# {city} not found. Skipping...
# Processing Record 39 | dandong
# Processing Record 40 | dawei
# Processing Record 41 | butaritari
# Processing Record 42 | wulanhaote
# {city} not found. Skipping...
# Processing Record 43 | barentsburg
# {city} not found. Skipping...
# Processing Record 44 | yar-sale
# Processing Record 45 | taree
# Processing Record 46 | karauzyak
# {city} not found. Skipping...
# Processing Record 47 | kruisfontein
# Processing Record 48 | codrington
# Processing Record 49 | laguna
# Processing Record 50 | ibipeba
# Processing Record 51 | novaya chigla
# {city} not found. Skipping...
# Processing Record 52 | hilo
# Processing Record 53 | rio cuarto
# {city} not found. Skipping...
# Processing Record 54 | rabo de peixe
# {city} not found. Skipping...
# Processing Record 55 | qasigiannguit
# Processing Record 56 | fairbanks
# Processing Record 57 | itoman
# Processing Record 58 | punta arenas
# {city} not found. Skipping...
# Processing Record 59 | vao
# Processing Record 60 | omachi
# Processing Record 61 | castro
# Processing Record 62 | airai
# Processing Record 63 | grand gaube
# {city} not found. Skipping...
# Processing Record 64 | puerto ayora
# {city} not found. Skipping...
# Processing Record 65 | hithadhoo
# Processing Record 66 | illoqqortoormiut
# {city} not found. Skipping...
# Processing Record 67 | busselton
# Processing Record 68 | qaanaaq
# Processing Record 69 | rikitea
# Processing Record 70 | huesca
# Processing Record 71 | srednekolymsk
# Processing Record 72 | luwuk
# Processing Record 73 | pangnirtung
# Processing Record 74 | kapaa
# Processing Record 75 | ayios matthaios
# {city} not found. Skipping...
# Processing Record 76 | kirakira
# Processing Record 77 | puerto leguizamo
# {city} not found. Skipping...
# Processing Record 78 | albany
# Processing Record 79 | ca mau
# {city} not found. Skipping...
# Processing Record 80 | nome
# Processing Record 81 | beloha
# Processing Record 82 | sept-iles
# Processing Record 83 | oktyabrskoye
# Processing Record 84 | luena
# Processing Record 85 | arraial do cabo
# {city} not found. Skipping...
# Processing Record 86 | hurghada
# Processing Record 87 | bage
# Processing Record 88 | klaksvik
# Processing Record 89 | muroto
# Processing Record 90 | taolanaro
# {city} not found. Skipping...
# Processing Record 91 | chapais
# Processing Record 92 | kawana waters
# {city} not found. Skipping...
# Processing Record 93 | east london
# {city} not found. Skipping...
# Processing Record 94 | moerai
# Processing Record 95 | bengkulu
# Processing Record 96 | barrow
# Processing Record 97 | touros
# Processing Record 98 | tawang
# Processing Record 99 | turbat
# Processing Record 100 | manicore
# Processing Record 101 | lagoa
# Processing Record 102 | guildford
# Processing Record 103 | solovetskiy
# {city} not found. Skipping...
# Processing Record 104 | salalah
# Processing Record 105 | tual
# Processing Record 106 | fort nelson
# {city} not found. Skipping...
# Processing Record 107 | akdepe
# Processing Record 108 | san cristobal
# {city} not found. Skipping...
# Processing Record 109 | thompson
# Processing Record 110 | hami
# Processing Record 111 | mastung
# Processing Record 112 | zyryanka
# Processing Record 113 | jamestown
# Processing Record 114 | belushya guba
# {city} not found. Skipping...
# Processing Record 115 | katsuura
# Processing Record 116 | hasaki
# Processing Record 117 | grenada
# Processing Record 118 | rostaq
# {city} not found. Skipping...
# Processing Record 119 | tiruvottiyur
# {city} not found. Skipping...
# Processing Record 120 | yulara
# Processing Record 121 | sentyabrskiy
# {city} not found. Skipping...
# Processing Record 122 | san luis
# {city} not found. Skipping...
# Processing Record 123 | tasiilaq
# Processing Record 124 | soverato
# Processing Record 125 | semey
# Processing Record 126 | nochistlan
# Processing Record 127 | teguise
# Processing Record 128 | chokurdakh
# Processing Record 129 | norman wells
# {city} not found. Skipping...
# Processing Record 130 | saskylakh
# Processing Record 131 | mataura
# Processing Record 132 | sao manuel
# {city} not found. Skipping...
# Processing Record 133 | saint-philippe
# Processing Record 134 | carnarvon
# Processing Record 135 | diego de almagro
# {city} not found. Skipping...
# Processing Record 136 | marienburg
# Processing Record 137 | tsiroanomandidy
# Processing Record 138 | kutum
# Processing Record 139 | gornopravdinsk
# Processing Record 140 | petatlan
# Processing Record 141 | ribeira grande
# {city} not found. Skipping...
# Processing Record 142 | komsomolskiy
# Processing Record 143 | mehamn
# Processing Record 144 | severo-kurilsk
# Processing Record 145 | meadow lake
# Processing Record 146 | dikson
# Processing Record 147 | carbonia
# Processing Record 148 | faanui
# Processing Record 149 | kodiak
# Processing Record 150 | carutapera
# Processing Record 151 | najran
# Processing Record 152 | arlit
# Processing Record 153 | richards bay
# {city} not found. Skipping...
# Processing Record 154 | sumbawa
# {city} not found. Skipping...
# Processing Record 155 | ayaviri
# Processing Record 156 | ponta do sol
# {city} not found. Skipping...
# Processing Record 157 | humberto de campos
# {city} not found. Skipping...
# Processing Record 158 | monchegorsk
# Processing Record 159 | anandnagar
# Processing Record 160 | meulaboh
# Processing Record 161 | upernavik
# Processing Record 162 | kalmunai
# Processing Record 163 | mlonggo
# Processing Record 164 | kloulklubed
# Processing Record 165 | qostanay
# Processing Record 166 | amderma
# {city} not found. Skipping...
# Processing Record 167 | camana
# Processing Record 168 | esperance
# Processing Record 169 | payakumbuh
# Processing Record 170 | khatanga
# Processing Record 171 | saint george
# {city} not found. Skipping...
# Processing Record 172 | kota tinggi
# {city} not found. Skipping...
# Processing Record 173 | hambantota
# Processing Record 174 | victoria
# Processing Record 175 | bardiyah
# Processing Record 176 | vanimo
# Processing Record 177 | alofi
# Processing Record 178 | fremont
# Processing Record 179 | santa cruz
# Processing Record 180 | coquimbo
# Processing Record 181 | hudiksvall
# Processing Record 182 | half moon bay
# {city} not found. Skipping...
# Processing Record 183 | avarua
# Processing Record 184 | mahebourg
# Processing Record 185 | souillac
# Processing Record 186 | ondjiva
# Processing Record 187 | padang
# Processing Record 188 | maroantsetra
# Processing Record 189 | samusu
# {city} not found. Skipping...
# Processing Record 190 | port-de-bouc
# Processing Record 191 | brawley
# Processing Record 192 | ancud
# Processing Record 193 | ballina
# Processing Record 194 | luganville
# Processing Record 195 | alotau
# {city} not found. Skipping...
# Processing Record 196 | zhigansk
# Processing Record 197 | port lincoln
# {city} not found. Skipping...
# Processing Record 198 | lavrentiya
# Processing Record 199 | caohe
# Processing Record 200 | romitan
# Processing Record 201 | rocha
# Processing Record 202 | hay river
# {city} not found. Skipping...
# Processing Record 203 | isangel
# Processing Record 204 | rio grande
# Processing Record 205 | bet shemesh
# {city} not found. Skipping...
# Processing Record 206 | torbay
# Processing Record 207 | tuatapere
# Processing Record 208 | venancio aires
# {city} not found. Skipping...
# Processing Record 209 | banda aceh
# {city} not found. Skipping...
# Processing Record 210 | cayenne
# Processing Record 211 | ahipara
# Processing Record 212 | port blair
# {city} not found. Skipping...
# Processing Record 213 | cherskiy
# Processing Record 214 | umzimvubu
# {city} not found. Skipping...
# Processing Record 215 | ayagoz
# Processing Record 216 | mar del plata
# {city} not found. Skipping...
# Processing Record 217 | chuy
# Processing Record 218 | nantucket
# Processing Record 219 | ilulissat
# Processing Record 220 | mitchell
# Processing Record 221 | mao
# Processing Record 222 | cockburn town
# {city} not found. Skipping...
# Processing Record 223 | kondinskoye
# Processing Record 224 | moradabad
# Processing Record 225 | jiroft
# {city} not found. Skipping...
# Processing Record 226 | shache
# Processing Record 227 | hualmay
# Processing Record 228 | farmington
# Processing Record 229 | broome
# Processing Record 230 | jardim
# Processing Record 231 | udayagiri
# Processing Record 232 | vigrestad
# Processing Record 233 | eldikan
# {city} not found. Skipping...
# Processing Record 234 | brae
# Processing Record 235 | hasanabad
# Processing Record 236 | oranjemund
# Processing Record 237 | pandan
# Processing Record 238 | los llanos de aridane
# {city} not found. Skipping...
# Processing Record 239 | knysna
# Processing Record 240 | santa rosa
# Processing Record 241 | tumannyy
# {city} not found. Skipping...
# Processing Record 242 | silver city
# {city} not found. Skipping...
# Processing Record 243 | kavieng
# Processing Record 244 | bredasdorp
# Processing Record 245 | vila velha
# {city} not found. Skipping...
# Processing Record 246 | sisimiut
# Processing Record 247 | sterling
# Processing Record 248 | henties bay
# {city} not found. Skipping...
# Processing Record 249 | benicarlo
# Processing Record 250 | diffa
# Processing Record 251 | cravo norte
# {city} not found. Skipping...
# Processing Record 252 | ostrovnoy
# Processing Record 253 | martin
# Processing Record 254 | paamiut
# Processing Record 255 | okhtyrka
# Processing Record 256 | balabac
# Processing Record 257 | maningrida
# Processing Record 258 | marsaxlokk
# Processing Record 259 | san patricio
# {city} not found. Skipping...
# Processing Record 260 | tiksi
# Processing Record 261 | lumphat
# Processing Record 262 | samarinda
# Processing Record 263 | tarragona
# Processing Record 264 | knokke-heist
# Processing Record 265 | cabo san lucas
# {city} not found. Skipping...
# Processing Record 266 | zhuhai
# Processing Record 267 | mayo
# Processing Record 268 | talnakh
# Processing Record 269 | bandarbeyla
# Processing Record 270 | baykit
# Processing Record 271 | paita
# Processing Record 272 | manvi
# Processing Record 273 | kaitangata
# Processing Record 274 | warqla
# {city} not found. Skipping...
# Processing Record 275 | kattivakkam
# Processing Record 276 | amapa
# Processing Record 277 | bambous virieux
# {city} not found. Skipping...
# Processing Record 278 | poum
# Processing Record 279 | shakhtinsk
# Processing Record 280 | lazaro cardenas
# {city} not found. Skipping...
# Processing Record 281 | dekar
# Processing Record 282 | goreloye
# Processing Record 283 | dunedin
# Processing Record 284 | lewistown
# Processing Record 285 | marzuq
# Processing Record 286 | saleaula
# {city} not found. Skipping...
# Processing Record 287 | mogadishu
# Processing Record 288 | taltal
# Processing Record 289 | turtkul
# {city} not found. Skipping...
# Processing Record 290 | wattegama
# Processing Record 291 | pisco
# Processing Record 292 | provideniya
# Processing Record 293 | port elizabeth
# {city} not found. Skipping...
# Processing Record 294 | oloron-sainte-marie
# Processing Record 295 | tupi paulista
# {city} not found. Skipping...
# Processing Record 296 | ternate
# Processing Record 297 | itarema
# Processing Record 298 | geraldton
# Processing Record 299 | rawson
# Processing Record 300 | tautira
# Processing Record 301 | bentiu
# Processing Record 302 | conceicao do araguaia
# {city} not found. Skipping...
# Processing Record 303 | sevierville
# Processing Record 304 | mabaruma
# Processing Record 305 | anton lizardo
# {city} not found. Skipping...
# Processing Record 306 | churapcha
# Processing Record 307 | merke
# Processing Record 308 | acapulco
# Processing Record 309 | nemuro
# Processing Record 310 | celestun
# Processing Record 311 | nikel
# Processing Record 312 | chumikan
# Processing Record 313 | sexsmith
# Processing Record 314 | tsihombe
# {city} not found. Skipping...
# Processing Record 315 | nakamura
# Processing Record 316 | lapinigan
# Processing Record 317 | sola
# Processing Record 318 | praia
# Processing Record 319 | sioux lookout
# {city} not found. Skipping...
# Processing Record 320 | lebu
# Processing Record 321 | georgetown
# Processing Record 322 | kitsuki
# Processing Record 323 | alamogordo
# Processing Record 324 | thilogne
# {city} not found. Skipping...
# Processing Record 325 | tabou
# Processing Record 326 | narsaq
# Processing Record 327 | wesel
# Processing Record 328 | krasnyy yar
# {city} not found. Skipping...
# Processing Record 329 | griffith
# Processing Record 330 | kavaratti
# Processing Record 331 | maralal
# Processing Record 332 | formoso do araguaia
# {city} not found. Skipping...
# Processing Record 333 | redmond
# Processing Record 334 | khorixas
# Processing Record 335 | kahului
# Processing Record 336 | plettenberg bay
# {city} not found. Skipping...
# Processing Record 337 | necochea
# Processing Record 338 | harper
# Processing Record 339 | nizwa
# Processing Record 340 | alta floresta
# {city} not found. Skipping...
# Processing Record 341 | bikaner
# Processing Record 342 | hofn
# Processing Record 343 | vicuna
# Processing Record 344 | mazagao
# Processing Record 345 | north bend
# {city} not found. Skipping...
# Processing Record 346 | corrientes
# Processing Record 347 | port-gentil
# Processing Record 348 | road town
# {city} not found. Skipping...
# Processing Record 349 | sukhumi
# Processing Record 350 | jinchang
# Processing Record 351 | palabuhanratu
# {city} not found. Skipping...
# Processing Record 352 | general pico
# {city} not found. Skipping...
# Processing Record 353 | khash
# Processing Record 354 | parnamirim
# Processing Record 355 | khonuu
# {city} not found. Skipping...
# Processing Record 356 | porto walter
# {city} not found. Skipping...
# Processing Record 357 | porto
# Processing Record 358 | nokaneng
# Processing Record 359 | labelle
# Processing Record 360 | san quintin
# {city} not found. Skipping...
# Processing Record 361 | pilar
# Processing Record 362 | dongsheng
# Processing Record 363 | los lunas
# {city} not found. Skipping...
# Processing Record 364 | grindavik
# Processing Record 365 | sitka
# Processing Record 366 | vardo
# Processing Record 367 | kakonko
# Processing Record 368 | kippen
# Processing Record 369 | abay
# Processing Record 370 | ust-tsilma
# Processing Record 371 | monte alegre de minas
# {city} not found. Skipping...
# Processing Record 372 | martapura
# Processing Record 373 | matay
# Processing Record 374 | kroya
# Processing Record 375 | kupang
# Processing Record 376 | kilindoni
# Processing Record 377 | ambulu
# Processing Record 378 | amazar
# Processing Record 379 | cockburn harbour
# {city} not found. Skipping...
# Processing Record 380 | sinnamary
# Processing Record 381 | miranda
# Processing Record 382 | bathsheba
# Processing Record 383 | stoyba
# {city} not found. Skipping...
# Processing Record 384 | litovko
# Processing Record 385 | alugan
# Processing Record 386 | handan
# Processing Record 387 | sidi bu zayd
# {city} not found. Skipping...
# Processing Record 388 | port hardy
# {city} not found. Skipping...
# Processing Record 389 | coolum beach
# {city} not found. Skipping...
# Processing Record 390 | fortuna
# Processing Record 391 | kulhudhuffushi
# Processing Record 392 | sitio novo do tocantins
# {city} not found. Skipping...
# Processing Record 393 | saldanha
# Processing Record 394 | suna
# Processing Record 395 | samarai
# Processing Record 396 | derzhavinsk
# Processing Record 397 | champerico
# Processing Record 398 | opochka
# Processing Record 399 | zurrieq
# Processing Record 400 | kaseda
# Processing Record 401 | abha
# Processing Record 402 | mys shmidta
# {city} not found. Skipping...
# Processing Record 403 | upata
# Processing Record 404 | cidreira
# Processing Record 405 | guerrero negro
# {city} not found. Skipping...
# Processing Record 406 | iwanai
# Processing Record 407 | qandala
# Processing Record 408 | ambilobe
# Processing Record 409 | camacha
# Processing Record 410 | gat
# Processing Record 411 | aleksandrov gay
# {city} not found. Skipping...
# Processing Record 412 | pevek
# Processing Record 413 | hidrolandia
# Processing Record 414 | husavik
# Processing Record 415 | nishihara
# Processing Record 416 | iqaluit
# Processing Record 417 | ucluelet
# Processing Record 418 | tatawin
# Processing Record 419 | beyneu
# Processing Record 420 | killybegs
# Processing Record 421 | isla vista
# {city} not found. Skipping...
# Processing Record 422 | praxedis guerrero
# {city} not found. Skipping...
# Processing Record 423 | khurianwala
# {city} not found. Skipping...
# Processing Record 424 | krasnoselkup
# Processing Record 425 | mapiri
# Processing Record 426 | paramonga
# Processing Record 427 | tukrah
# Processing Record 428 | flinders
# Processing Record 429 | khromtau
# Processing Record 430 | san benito
# {city} not found. Skipping...
# Processing Record 431 | sao raimundo nonato
# {city} not found. Skipping...
# Processing Record 432 | nanortalik
# Processing Record 433 | turukhansk
# Processing Record 434 | port hawkesbury
# {city} not found. Skipping...
# Processing Record 435 | maues
# Processing Record 436 | vulcanesti
# Processing Record 437 | longyearbyen
# Processing Record 438 | saint-pierre
# Processing Record 439 | tevaitoa
# Processing Record 440 | yabrud
# Processing Record 441 | okhotsk
# Processing Record 442 | faya
# Processing Record 443 | hornepayne
# Processing Record 444 | valmiera
# Processing Record 445 | tanshui
# {city} not found. Skipping...
# Processing Record 446 | liverpool
# Processing Record 447 | yanam
# Processing Record 448 | yablonovo
# Processing Record 449 | ilo
# Processing Record 450 | te anau
# {city} not found. Skipping...
# Processing Record 451 | biak
# Processing Record 452 | berdigestyakh
# Processing Record 453 | taoudenni
# Processing Record 454 | inderborskiy
# {city} not found. Skipping...
# Processing Record 455 | katobu
# Processing Record 456 | wuning
# Processing Record 457 | sarai
# Processing Record 458 | tornio
# Processing Record 459 | high level
# {city} not found. Skipping...
# Processing Record 460 | mega
# Processing Record 461 | korla
# Processing Record 462 | lincoln
# Processing Record 463 | dunkirk
# Processing Record 464 | huimanguillo
# Processing Record 465 | leshukonskoye
# Processing Record 466 | budelsdorf
# Processing Record 467 | bowen
# Processing Record 468 | bolshaya irba
# {city} not found. Skipping...
# Processing Record 469 | nador
# Processing Record 470 | rakvere
# Processing Record 471 | batemans bay
# {city} not found. Skipping...
# Processing Record 472 | aklavik
# Processing Record 473 | kharp
# Processing Record 474 | hinton
# Processing Record 475 | sosnogorsk
# Processing Record 476 | namibe
# Processing Record 477 | dzhusaly
# {city} not found. Skipping...
# Processing Record 478 | owando
# Processing Record 479 | maniwaki
# Processing Record 480 | jakar
# Processing Record 481 | kerteh
# {city} not found. Skipping...
# Processing Record 482 | chitrakonda
# Processing Record 483 | tezu
# Processing Record 484 | ust-nera
# Processing Record 485 | ishcherskaya
# Processing Record 486 | berlevag
# Processing Record 487 | le port
# {city} not found. Skipping...
# Processing Record 488 | talaya
# Processing Record 489 | high prairie
# {city} not found. Skipping...
# Processing Record 490 | reefton
# {city} not found. Skipping...
# Processing Record 491 | mersing
# Processing Record 492 | de aar
# Processing Record 493 | ratnagiri
# Processing Record 494 | sorvag
# {city} not found. Skipping...
# Processing Record 495 | yanchukan
# {city} not found. Skipping...
# Processing Record 496 | la maddalena
# {city} not found. Skipping...
# Processing Record 497 | ambon
# Processing Record 498 | horsham
# Processing Record 499 | garwolin
# Processing Record 500 | grenfell
# Processing Record 501 | novikovo
# Processing Record 502 | tuktoyaktuk
# Processing Record 503 | mpophomeni
# Processing Record 504 | nara
# Processing Record 505 | alexandria
# Processing Record 506 | sao filipe
# {city} not found. Skipping...
# Processing Record 507 | burkhala
# {city} not found. Skipping...
# Processing Record 508 | juxian
# {city} not found. Skipping...
# Processing Record 509 | chiang khong
# {city} not found. Skipping...
# Processing Record 510 | kangaatsiaq
# Processing Record 511 | altay
# Processing Record 512 | katherine
# Processing Record 513 | isabela
# Processing Record 514 | floriano
# Processing Record 515 | san ignacio
# {city} not found. Skipping...
# Processing Record 516 | okha
# Processing Record 517 | avera
# Processing Record 518 | idrinskoye
# Processing Record 519 | karamay
# {city} not found. Skipping...
# Processing Record 520 | matara
# Processing Record 521 | vinces
# Processing Record 522 | pasighat
# Processing Record 523 | lerwick
# Processing Record 524 | rio verde de mato grosso
# {city} not found. Skipping...
# Processing Record 525 | odweyne
# Processing Record 526 | thaba-tseka
# Processing Record 527 | aswan
# Processing Record 528 | namatanai
# Processing Record 529 | kempsey
# Processing Record 530 | belmonte
# Processing Record 531 | lethem
# Processing Record 532 | tambura
# Processing Record 533 | montlucon
# Processing Record 534 | koyilandi
# {city} not found. Skipping...
# Processing Record 535 | makow mazowiecki
# {city} not found. Skipping...
# Processing Record 536 | puerto escondido
# {city} not found. Skipping...
# Processing Record 537 | gainesville
# Processing Record 538 | mpulungu
# Processing Record 539 | severo-yeniseyskiy
# Processing Record 540 | moose factory
# {city} not found. Skipping...
# Processing Record 541 | mitsamiouli
# Processing Record 542 | san jose
# {city} not found. Skipping...
# Processing Record 543 | dzhebariki-khaya
# Processing Record 544 | anadyr
# Processing Record 545 | dom pedrito
# {city} not found. Skipping...
# Processing Record 546 | antofagasta
# Processing Record 547 | waddan
# Processing Record 548 | grafton
# Processing Record 549 | shahrud
# Processing Record 550 | bubaque
# Processing Record 551 | fukuma
# Processing Record 552 | palmeira
# Processing Record 553 | itaiba
# Processing Record 554 | north vernon
# {city} not found. Skipping...
# Processing Record 555 | teya
# Processing Record 556 | ixtapa
# Processing Record 557 | praia da vitoria
# {city} not found. Skipping...
# Processing Record 558 | hervey bay
# {city} not found. Skipping...
# Processing Record 559 | pochutla
# Processing Record 560 | pundaguitan
# Processing Record 561 | obluche
# {city} not found. Skipping...
# Processing Record 562 | kadykchan
# {city} not found. Skipping...
# Processing Record 563 | cap malheureux
# {city} not found. Skipping...
# Processing Record 564 | bani walid
# {city} not found. Skipping...
# Processing Record 565 | marabba
# Processing Record 566 | kargasok
# Processing Record 567 | bilibino
# Processing Record 568 | mumford
# Processing Record 569 | luau
# Processing Record 570 | portland
# Processing Record 571 | urengoy
# Processing Record 572 | urumqi
# Processing Record 573 | one hundred mile house
# {city} not found. Skipping...
# Processing Record 574 | eforie
# {city} not found. Skipping...
# Processing Record 575 | emirdag
# Processing Record 576 | grand river south east
# {city} not found. Skipping...
# Processing Record 577 | roald
# Processing Record 578 | ziro
# Processing Record 579 | coulihaut
# {city} not found. Skipping...
# Processing Record 580 | corrales
# Processing Record 581 | longlac
# {city} not found. Skipping...
# Processing Record 582 | bereda
# Processing Record 583 | zlatoust
# Processing Record 584 | vestmannaeyjar
# Processing Record 585 | japura
# Processing Record 586 | clinton
# Processing Record 587 | kirovskiy
# Processing Record 588 | belluno
# Processing Record 589 | tanggu
# Processing Record 590 | mizdah
# Processing Record 591 | yebaishou
# Processing Record 592 | deputatskiy
# Processing Record 593 | lata
# Processing Record 594 | ruatoria
# {city} not found. Skipping...
# Processing Record 595 | kibre mengist
# {city} not found. Skipping...
# Processing Record 596 | mandla
# Processing Record 597 | bridlington
# Processing Record 598 | mossendjo
# Processing Record 599 | sukumo
# Processing Record 600 | qianan
# Processing Record 601 | ampanihy
# Processing Record 602 | requena
# Processing Record 603 | pudozh
# Processing Record 604 | gayny
# Processing Record 605 | portales
# Processing Record 606 | kangavar
# Processing Record 607 | devils lake
# {city} not found. Skipping...
# Processing Record 608 | edd
# Processing Record 609 | ribeira brava
# {city} not found. Skipping...
# Processing Record 610 | boende
# Processing Record 611 | merritt
# Processing Record 612 | seminole
# Processing Record 613 | korcula
# Processing Record 614 | sal rei
# {city} not found. Skipping...
# Processing Record 615 | vuktyl
# Processing Record 616 | ngukurr
# {city} not found. Skipping...
# Processing Record 617 | wahran
# {city} not found. Skipping...
# Processing Record 618 | uttaradit
# Processing Record 619 | dzaoudzi
# Processing Record 620 | munkebo
# Processing Record 621 | shimanovsk
# Processing Record 622 | maniitsoq
# Processing Record 623 | cheremisinovo
# Processing Record 624 | kawalu
# Processing Record 625 | banfora
# Processing Record 626 | banjar
# Processing Record 627 | constitucion
# Processing Record 628 | gunjur
# Processing Record 629 | attawapiskat
# {city} not found. Skipping...
# Processing Record 630 | quelimane
# Processing Record 631 | gushikawa
# Processing Record 632 | ngunguru
# Processing Record 633 | ust-koksa
# Processing Record 634 | turan
# Processing Record 635 | tura
# Processing Record 636 | casino
# Processing Record 637 | kaeo
# Processing Record 638 | carbonear
# Processing Record 639 | snasa
# Processing Record 640 | mutsamudu
# {city} not found. Skipping...
# Processing Record 641 | tarhunah
# {city} not found. Skipping...
# Processing Record 642 | borsa
# Processing Record 643 | keti bandar
# {city} not found. Skipping...
# Processing Record 644 | bairiki
# Processing Record 645 | hanyang
# Processing Record 646 | bratsk
# Processing Record 647 | lardos
# Processing Record 648 | praya
# Processing Record 649 | hulyaypole
# Processing Record 650 | bojkovice
# Processing Record 651 | hobyo
# Processing Record 652 | havre-saint-pierre
# Processing Record 653 | pitimbu
# Processing Record 654 | doctor pedro p. pena
# {city} not found. Skipping...
# Processing Record 655 | galle
# Processing Record 656 | qaqortoq
# Processing Record 657 | darhan
# Processing Record 658 | labutta
# {city} not found. Skipping...
# Processing Record 659 | shubarkuduk
# Processing Record 660 | sakakah
# Processing Record 661 | bozdar
# Processing Record 662 | kampene
# Processing Record 663 | pindiga
# Processing Record 664 | tucuman
# Processing Record 665 | keningau
# Processing Record 666 | srandakan
# Processing Record 667 | kismayo
# Processing Record 668 | ekhabi
# Processing Record 669 | siva
# Processing Record 670 | elliot
# Processing Record 671 | waingapu
# Processing Record 672 | auch
# Processing Record 673 | rio gallegos
# {city} not found. Skipping...
# Processing Record 674 | wanaka
# Processing Record 675 | bulawayo
# Processing Record 676 | gorno-chuyskiy
# {city} not found. Skipping...
# Processing Record 677 | verkhnyaya inta
# {city} not found. Skipping...
# Processing Record 678 | gouyave
# Processing Record 679 | lorengau
# Processing Record 680 | iracoubo
# Processing Record 681 | wentzville
# Processing Record 682 | aasiaat
# Processing Record 683 | havelock
# Processing Record 684 | benalla
# Processing Record 685 | puri
# Processing Record 686 | cochrane
# Processing Record 687 | yining
# Processing Record 688 | buala
# Processing Record 689 | xanlar
# Processing Record 690 | mormugao
# Processing Record 691 | kardailovo
# Processing Record 692 | pacific grove
# {city} not found. Skipping...
# Processing Record 693 | zhigalovo
# Processing Record 694 | grand-santi
# Processing Record 695 | mount isa
# {city} not found. Skipping...
# Processing Record 696 | dingle
# Processing Record 697 | siocon
# Processing Record 698 | olafsvik
# Processing Record 699 | rungata
# {city} not found. Skipping...
# Processing Record 700 | kon tum
# {city} not found. Skipping...
# Processing Record 701 | kefamenanu
# Processing Record 702 | lalsk
# Processing Record 703 | horki
# Processing Record 704 | wenling
# Processing Record 705 | fort collins
# {city} not found. Skipping...
# Processing Record 706 | veraval
# Processing Record 707 | tibati
# Processing Record 708 | burica
# {city} not found. Skipping...
# Processing Record 709 | suntar
# Processing Record 710 | mount gambier
# {city} not found. Skipping...
# Processing Record 711 | bar harbor
# {city} not found. Skipping...
# Processing Record 712 | tiarei
# Processing Record 713 | burayevo
# Processing Record 714 | bansang
# Processing Record 715 | bajo baudo
# {city} not found. Skipping...
# Processing Record 716 | ous
# Processing Record 717 | san borja
# {city} not found. Skipping...
# Processing Record 718 | connersville
# Processing Record 719 | neuquen
# Processing Record 720 | seoul
# Processing Record 721 | burns lake
# {city} not found. Skipping...
# Processing Record 722 | peniche
# Processing Record 723 | karratha
# Processing Record 724 | wad rawah
# {city} not found. Skipping...
# Processing Record 725 | sorland
# Processing Record 726 | hearst
# Processing Record 727 | abu dhabi
# {city} not found. Skipping...
# Processing Record 728 | tateyama
# Processing Record 729 | mawlaik
# Processing Record 730 | dwarka
# Processing Record 731 | lompoc
# Processing Record 732 | cumaribo
# {city} not found. Skipping...
# Processing Record 733 | perth
# Processing Record 734 | lagoa vermelha
# {city} not found. Skipping...
# Processing Record 735 | puerto del rosario
# {city} not found. Skipping...
# Processing Record 736 | korgen
# Processing Record 737 | sangueya
# Processing Record 738 | akyab
# Processing Record 739 | semirom
# Processing Record 740 | moses lake
# {city} not found. Skipping...
# Processing Record 741 | san rafael
# {city} not found. Skipping...
# Processing Record 742 | muisne
# Processing Record 743 | balikpapan
# Processing Record 744 | zachagansk
# {city} not found. Skipping...
# Processing Record 745 | aykhal

# %%
citiespd.replace('', np.nan, inplace=True)
citiespd.dropna(inplace=True)
citiespd.to_csv("cityweather.csv", encoding="utf-8", index=False)
citiespd.describe()
# Out:
#          Latitude   Longitude    Humidity  Cloudiness  Max Temperature  \
# count  564.000000  564.000000  564.000000  564.000000       564.000000
# mean    22.868712   28.022157   67.893617   54.588652       289.600621
# std     31.884450   86.118627   23.811337   38.723013        11.061675
# min    -54.800000 -175.200000    8.000000    0.000000       259.150000
# 25%     -2.599325  -48.461500   56.000000   20.000000       280.377500
# 50%     28.294000   31.666650   72.000000   61.000000       290.285000
# 75%     50.134250  100.876650   87.000000   96.000000       298.710000
# max     78.218600  178.416700  100.000000  100.000000       316.210000
#
#        Wind Speed          Date
# count  564.000000  5.640000e+02
# mean     3.525496  1.619328e+09
# std      2.369868  2.213071e+02
# min      0.080000  1.619328e+09
# 25%      1.790000  1.619328e+09
# 50%      3.090000  1.619329e+09
# 75%      4.630000  1.619329e+09
# max     16.460000  1.619329e+09

# %% [markdown]
# ### Plotting the Data
# ##### Labeling of the plots using plot titles (including date of analysis) and axes labels.

# %% [markdown]
# #### Latitude vs Max Temperature Plot

# %%
plt.scatter(citiespd["Latitude"], citiespd["Max Temperature"], marker="o")
plt.title("City Latitude vs Max Temperature (04/24/21)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("TemperatureInWorldCities.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(citiespd["Latitude"], citiespd["Humidity"], marker="o")
plt.title("City Latitude vs Humidity (04/24/21)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("HumidityInWorldCities.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(citiespd["Latitude"], citiespd["Cloudiness"], marker="o")
plt.title("City Latitude vs Cloudiness (04/24/21)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("CloudinessInWorldCities.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(citiespd["Latitude"], citiespd["Wind Speed"], marker="o")
plt.title("City Latitude vs Wind Speed (04/24/21)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("WindSpeedInWorldCities.png")

# %% [markdown]
# ### Linear Regression

# %%
north = citiespd.query('Latitude >= 0')
south = citiespd.query('Latitude < 0')
south.head()
# Out:
#             City  Latitude  Longitude  Humidity  Cloudiness  Max Temperature  \
# 0   jacareacanga   -6.2222   -57.7528      87.0        80.0           298.09
# 1          vaini  -21.2000  -175.2000      83.0        20.0           300.15
# 3        malanje   -9.5402    16.3410      96.0        92.0           290.22
# 5         hobart  -42.8794   147.3294      44.0        75.0           290.37
# 11        atuona   -9.8000  -139.0333      77.0        39.0           299.99
#
#     Wind Speed Country          Date
# 0         0.39      BR  1.619329e+09
# 1         1.54      TO  1.619328e+09
# 3         0.76      AO  1.619329e+09
# 5         9.26      AU  1.619328e+09
# 11        6.25      PF  1.619329e+09

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(north["Latitude"], north["Max Temperature"], marker="o")
plt.title("Northern Hemisphere City Latitude vs Max Temperature (04/24/21)")
plt.grid(True)
x_values=north["Latitude"]
y_values=north["Max Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.annotate(line_eq,(45,300),fontsize=12,color="red")
plt.show()
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: -0.8705

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(south["Latitude"], south["Max Temperature"], marker="o")
plt.title("Southern Hemisphere City Latitude vs Max Temperature (04/24/21)")
plt.grid(True)
x_values=south["Latitude"]
y_values=south["Max Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-20,280),fontsize=12,color="red")
plt.show()
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.6881

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(north["Latitude"], north["Humidity"], marker="o")
plt.title("Northern Hemisphere City Latitude vs Humidity (04/24/21)")
plt.grid(True)
x_values=north["Latitude"]
y_values=north["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.annotate(line_eq,(50,10),fontsize=12,color="red")
plt.show()
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.1786

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(south["Latitude"], south["Humidity"], marker="o")
plt.title("Northern Hemisphere City Latitude vs Humidity (04/24/21)")
plt.grid(True)
x_values=south["Latitude"]
y_values=south["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-55,30),fontsize=12,color="red")
plt.show()
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.1755

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude

# %%
plt.scatter(north["Latitude"], north["Cloudiness"], marker="o")
plt.title("Northern Hemisphere City Latitude vs Cloudiness (04/24/21)")
plt.grid(True)
x_values=north["Latitude"]
y_values=north["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.annotate(line_eq,(25,50),fontsize=12,color="red")
plt.show()
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.1563

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(south["Latitude"], south["Cloudiness"], marker="o")
plt.title("Southern Hemisphere City Latitude vs Cloudiness (04/24/21)")
plt.grid(True)
x_values=south["Latitude"]
y_values=south["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-55,60),fontsize=13,color="red")
plt.show()
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.19

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(north["Latitude"], north["Wind Speed"], marker="o")
plt.title("Northern Hemisphere City Latitude vs Wind Speed (04/24/21)")
plt.grid(True)
x_values=north["Latitude"]
y_values=north["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.annotate(line_eq,(0,12),fontsize=13,color="red")
plt.show()
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.1889

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(south["Latitude"], south["Wind Speed"], marker="o")
plt.title("Southern Hemisphere City Latitude vs Wind Speed (04/24/21)")
plt.grid(True)
x_values=south["Latitude"]
y_values=south["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-55,8),fontsize=13,color="red")
plt.show()
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: -0.1377
